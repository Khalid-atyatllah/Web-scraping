# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.jumia.ma/catalog/?q=adaptateur+iphone+usb"
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

items = soup.find_all('article',class_='prd _fb col c-prd' )

for article in items:
    price = article.find('div', class_="prc").get_text()
    name = article.find('h3', class_='name').get_text()
    stars_div = article.find('div', class_="stars _s")
    img_url = article.find('img', class_='img')['data-src']

    if stars_div:
        star_rating_text = stars_div.get_text(strip=True)
        stars = "/".join(star_rating_text.split(" out of "))
    else:
        stars = "N/A"
        
        
    print('name: ', name)
    print('stars: ', stars)
    print('price: ', price)
    print('img url: ', img_url)
    print( )
# Out:
# name:  Plustar Adaptateur USB OTG pour iPhone iOS Transmission de données
# stars:  3/5
# price:  99.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/66/927316/1.jpg?3805
#
# name:  USB vers HDMI câble convertisseur adaptateur MHL pour IPhone IPad  Android vers projecteur et télévision
# stars:  N/A
# price:  200.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/35/506783/1.jpg?6204
#
# name:  Adaptateur Chargeur 20w de Iphone 12 series usb Type-C Power Adapter avec Cable .
# stars:  N/A
# price:  99.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/51/996016/1.jpg?9387
#
# name:  Adaptateur Chargeur 20w de Iphone 12 series usb Type-C Power Adapter avec Cable .
# stars:  N/A
# price:  225.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/61/292006/1.jpg?3384
#
# name:  Adaptateur Chargeur rapide compatible avec iPhone PD 20W USB-C + Câble USB-C vers Lightning
# stars:  N/A
# price:  119.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/96/908794/1.jpg?9805
#
# name:  Apple Adaptateur Secteur USB-C 20W 100% Originale Chargeur Pour iPhone AirPods iPad Et Apple Watch
# stars:  5/5
# price:  229.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/60/987155/1.jpg?0114
#
# name:  Adaptateur Chargeur 20w de Iphone 12 series usb Type-C Power Adapter avec Cable .
# stars:  5/5
# price:  96.80 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/87/557595/1.jpg?8986
#
# name:  Adaptateur Chargeur 20w de Iphone 12 series usb Type-C Power Adapter avec Cable .
# stars:  N/A
# price:  99.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/52/527285/1.jpg?3805
#
# name:  Adaptateur OTG, convertisseurs de données pour iphone / iPad IOS 13 a 15 à USB 3.0, support U Disk
# stars:  4/5
# price:  95.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/97/309065/1.jpg?6666
#
# name:  Apple Chargeur iphone 35 W à double port USB-C Interface de Sortie: 2 ports C Chargeur Pour iPhone 13 /14
# stars:  2.5/5
# price:  249.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/29/605916/1.jpg?5883
#
# name:  adaptateur cable Transfert OTG iphone Lightning A Usb 3.0 Plug and Play
# stars:  N/A
# price:  155.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/47/627126/1.jpg?0867
#
# name:  Adaptateur Chargeur 20w de Iphone 12 series usb Type-C Power Adapter avec Cable .
# stars:  4/5
# price:  149.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/68/282865/1.jpg?7372
#
# name:  Chargeur USB C Adaptateur avec  Câble USB C vers Lightning Compatible avec iPhone SE 2020/12/12 Mini/12 Pro Max/11/11 Pro Max/Xs/XR/X et plus(Blanc)
# stars:  N/A
# price:  149.99 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/57/071774/1.jpg?0753
#
# name:  Genetic Denim Adaptateur Secteur USB-C 20W pour iPhone 12 pro max  11 pro and cable type c
# stars:  3.8/5
# price:  99.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product
00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/79/147373/1.jpg?3307
#
# name:  Chargeur double USB pour voiture, charge rapide 3.0, pour iphone, xiaomi, Huawei, Samsung, adaptateur pour véhicule
# stars:  N/A
# price:  57.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/37/291634/1.jpg?6103
#
# name:  Chargeur Secteur + Câble,pour iPhone 5 5S 5C 6 7 8 X Max - Blanc
# stars:  3.5/5
# price:  61.99 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/68/291283/1.jpg?2231
#
# name:  Adaptateur micro USB to Lightning pour iPhone
# stars:  N/A
# price:  19.89 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/05/105565/1.jpg?0491
#
# name:  Adaptateur Secteur USB Type-C PD 20W pour iPhone - Charge rapide
# stars:  4.5/5
# price:  99.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/78/181065/1.jpg?1576
#
# name:  Adaptateur Secteur USB-C 20W compatible avec iPhone 12 pro max  11 pro and cable type c
# stars:  3/5
# price:  87.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/23/048155/1.jpg?5865
#
# name:  Adaptateur Charge Rapide 4 Ports USB-C 3.0 PD pour iPhone, Samsung Xiaomi - noir
# stars:  N/A
# price:  70.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/06/411536/1.jpg?1743
#
# name:  Chargeur Secteur + Câble, Adaptateur USB Universel Mural & Chargeur 1M Compatible avec iPhone 5 5S 5C 6 7 8 X Max - Blanc
# stars:  3.8/5
# price:  69.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/38/706783/1.jpg?7251
#
# name:  General Adaptateur Secteur USB Type-C PD 20W pour iPhone 12 Pro Max - Charge rapide
# stars:  N/A
# price:  99.00 Dhs
# img url:  https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/07/695665/1.jpg?2790

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

url = "https://www.jumia.ma/catalog/?q=adaptateur+iphone+usb"
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

items = soup.find_all('article', class_='prd _fb col c-prd')

data_list = []

for article in items:
    price = article.find('div', class_="prc").get_text()
    name = article.find('h3', class_='name').get_text()
    stars_div = article.find('div', class_="stars _s")
    img_url = article.find('img', class_='img')['data-src']

    if stars_div:
        star_rating_text = stars_div.get_text(strip=True)
        stars = "/".join(star_rating_text.split(" out of "))
    else:
        stars = "N/A"

    data = [price, name, stars, img_url]
    data_list.append(data)

header = ['price', 'name', 'stars', 'img_url']

with open('jumiaWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(data_list)

df = pd.read_csv('jumiaWebScraperDataset.csv')

df
# Out:
#          price                                               name  stars  \
# 0    99.00 Dhs  Plustar Adaptateur USB OTG pour iPhone iOS Tra...    3/5
# 1   200.00 Dhs  USB vers HDMI câble convertisseur adaptateur M...    NaN
# 2    99.00 Dhs  Adaptateur Chargeur 20w de Iphone 12 series us...    NaN
# 3   225.00 Dhs  Adaptateur Chargeur 20w de Iphone 12 series us...    NaN
# 4   119.00 Dhs  Adaptateur Chargeur rapide compatible avec iPh...    NaN
# 5   249.00 Dhs  Apple Chargeur iphone 35 W à double port USB-C...  2.5/5
# 6    96.80 Dhs  Adaptateur Chargeur 20w de Iphone 12 series us...    5/5
# 7   229.00 Dhs  Apple Adaptateur Secteur USB-C 20W 100% Origin...    5/5
# 8    99.00 Dhs  Adaptateur Chargeur 20w de Iphone 12 series us...    NaN
# 9    95.00 Dhs  Adaptateur OTG, convertisseurs de données pour...    4/5
# 10  155.00 Dhs  adaptateur cable Transfert OTG iphone Lightnin...    NaN
# 11  149.00 Dhs  Adaptateur Chargeur 20w de Iphone 12 series us...    4/5
# 12  149.99 Dhs  Chargeur USB C Adaptateur avec  Câble USB C ve...    NaN
# 13   99.00 Dhs  Genetic Denim Adaptateur Secteur USB-C 20W pou...  3.8/5
# 14   87.99 Dhs  Adaptateur Secteur USB-C 20W pour iPhone 12 pr...    2/5
# 15  449.00 Dhs  Apple Adaptateur Secteur USB-C 20W 100% Origin...    NaN
# 16   99.00 Dhs  Emy 12W Charge rapide 2USB chargeur adaptateur...    NaN
# 17  140.00 Dhs  Nouvelle charge  rapide 3,0 35W QC 3.0FAST Cha...    NaN
# 18   93.00 Dhs  General Adaptateur Secteur USB Type-C PD 20W p...    4/5
# 19   24.00 Dhs                   Micro USB Adaptateur Pour iPhone  3.8/5
# 20  199.00 Dhs  Apple Adaptateur Secteur USB-C 25w Original Ch...    NaN
# 21  129.00 Dhs  General Adaptateur Secteur USB Type-C - 20W po...    1/5
# 22  119.00 Dhs  Ldnio 18W Charge rapide USB chargeur adaptateu...    NaN
# 23  249.00 Dhs  Apple Adaptateur Secteur USB-C 20W original Ch...    NaN
# 24   99.00 Dhs  Chargeur 65W 5Ports USB adaptateur de charge p...    NaN
# 25  249.00 Dhs  Apple Adaptateur Secteur USB-C 35W Originale C...    NaN
# 26   74.99 Dhs  Chargeur Adaptateur secteur USB-C 18W Blanc co...  3.7/5
# 27   17.99 Dhs  Adaptateur vers Micro-Usb Femelle pour Apple i...    NaN
# 28   75.00 Dhs  Magnetic câble Magnetic Haute Qualite micro US...    NaN
# 29  289.00 Dhs  Remax NOUVEAU RS-X1 Chargeur de voyage mural A...    NaN
# 30   70.00 Dhs  Kit Adaptateur Lightning mâle Iphone / Micro U...    1/5
# 31   19.00 Dhs                   Adaptateur micro USB pour iPhone    NaN
# 32  119.00 Dhs  Adaptateur Secteur USB-C  pour iPhone 12 pro m...    1/5
# 33   57.00 Dhs  Chargeur double USB pour voiture, charge rapid...    NaN
# 34   61.99 Dhs  Chargeur Secteur + Câble,pour iPhone 5 5S 5C 6...  3.5/5
# 35   99.00 Dhs  Adaptateur Secteur USB Type-C PD 20W pour iPho...  4.5/5
# 36   19.89 Dhs      Adaptateur micro USB to Lightning pour iPhone    NaN
# 37   87.00 Dhs  Adaptateur Secteur USB-C 20W compatible avec i...    3/5
# 38   69.00 Dhs  Chargeur Secteur + Câble, Adaptateur USB Unive...  3.8/5
# 39   99.00 Dhs  General Adaptateur Secteur USB Type-C PD 20W p...    NaN
#
#                                               img_url
# 0   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 1   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 2   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 3   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 4   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 5   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 6   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 7   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 8   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 9   https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 10  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 11  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 12  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 13  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 14  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 15  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 16  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 17  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 18  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 19  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 20  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 21  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 22  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 23  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 24  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 25  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 26  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 27  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 28  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 29  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 30  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 31  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 32  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 33  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 34  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 35  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 36  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 37  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 38  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
# 39  https://ma.jumia.is/unsafe/fit-in/300x300/filt...
